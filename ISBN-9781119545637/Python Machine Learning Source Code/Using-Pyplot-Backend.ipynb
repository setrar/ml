# %%
using Plots; pyplot()  # This activates the PyPlot backend
# Out:
# Plots.PyPlotBackend()

# %%
# Data to plot
labels = ["Python", "Java", "C++", "Ruby"]
sizes = [215, 130, 245, 210]
colors = ["gold", "yellowgreen", "lightcoral", "lightskyblue"]
explode = (0.1, 0, 0, 0)  # explode the 1st slice

# Create the pie chart
fig, ax = PyPlot.subplots()
ax[:pie](sizes
    , explode=explode
    , labels=labels
    , colors=colors
    , autopct="%1.1f%%"
    , shadow=true
    , startangle=140
)

ax[:axis]("equal")  # Equal aspect ratio ensures that pie is drawn as a circle.

# Display the plot
# show() # sys:1: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# (-1.2038796791984885, 1.1049454538882466, -1.0999997591542812, 1.0999999448083795)

# %%
# pyplot_piechart.jl
#
#	Demonstrate plotting of pie charts
#
# gizmaa (https://gist.github.com/gizmaa/7214002)
# Julia 1.1.0
# Created: 29.10.13
# Last Edit: 10.05.19


#################
#  Create Data  #
#################
labels = ["Lager";"Pilsner";"Stout";"IPA"]
colors = ["yellowgreen";"gold";"lightskyblue";"lightcoral"]
sizes = [15; 30; 45; 10]
explode = zeros(length(sizes))
explode[2] = 0.1 # Move slice 2 out by 0.1
font = Dict("fontname"=>"Sans","weight"=>"semibold")

###############
#  Pie Chart  #
###############
# fig = PyPlot.plot("pyplot_piechart"
    # ,figsize=(10,10)
# )
p = PyPlot.pie(sizes
		, labels=labels
		, shadow=true
		, startangle=90
		, explode=explode
		, colors=colors
		, autopct="%1.1f%%"
		, textprops=font
        # , title = "Beer"
        # , axis = "equal"
)
PyPlot.title("Beer")
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject Text(0.5, 1.0, 'Beer')
